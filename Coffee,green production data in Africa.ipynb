# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from statistics import mean, variance, stdev, mode, median
import pandas

# %%
data = pandas.read_csv("un coffee.csv")
africa_array=["Algeria", "Angola", "Benin", "Botswana", "Burkina", "Burundi", "Cameroon", "Cape Verde", "Central African Republic", "Chad", "Comoros", "Congo", "Democratic Republic of Congo", "Djibouti", "Egypt", "Equatorial Guinea", "Eritrea", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Ivory Coast", "Kenya", "Lesotho", "Liberia", "Libya", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Morocco", "Mozambique", "Namibia", "Niger", "Nigeria", "Rwanda", "Sao Tome and Principe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa", "South Sudan", "Sudan", "Swaziland", "Tanzania", "Togo", "Tunisia", "Uganda", "Zambia", "Zimbabwe"]

data=data[data['country'].isin(africa_array)]
data.set_index('country', inplace=True)

data=data.sort_values('2010')
data
# Out:
#                                 2010    2011    2012    2013    2014    2015  \
# country
# Morocco                            0       0       0       0       0       0
# Botswana                           4       5       5       6       3       2
# Cape Verde                         4       5       5       5       3       3
# Chad                               4       5       5       5       3       3
# Tunisia                            5       3       2       2       4       3
# Mauritania                         6       6       6       0       0       3
# Egypt                             12       7       6       6       7       7
# Somalia                           57      53      63      67      71      83
# Benin                             60      65      68      70      62      51
# Mali                              67      76      65      87      56      69
# Senegal                           79      79      79      86      87      91
# ...

# %%
for year in range(2010, 2019):
    data.plot.bar(y=str(year),figsize=(12,12),title=str(year))
    plt.figure(figsize=(50,50))
    #plt.title("a graph of coffee,green production in Africa")
    #plt.xlabel("country")
    #plt.ylabel("amount produced")
    plt.show()

# %%
vertical=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']

# %%
data[vertical].mean()
# Out:
# 2010    22497.019231
# 2011    21310.807692
# 2012    21183.288462
# 2013    24126.807692
# 2014    25502.634615
# 2015    26415.192308
# 2016    26439.615385
# 2017    26543.903846
# 2018    26683.673077
# 2019    26923.826923
# dtype: float64

# %%
data[vertical].std()
# Out:
# 2010    58392.489461
# 2011    59215.405957
# 2012    49274.669138
# 2013    64076.684257
# 2014    67660.253364
# 2015    72040.208844
# 2016    72615.427702
# 2017    72499.913010
# 2018    72760.813369
# 2019    74195.229997
# dtype: float64

# %%
data[vertical].var()
# Out:
# 2010    3.409683e+09
# 2011    3.506464e+09
# 2012    2.427993e+09
# 2013    4.105821e+09
# 2014    4.577910e+09
# 2015    5.189792e+09
# 2016    5.273000e+09
# 2017    5.256237e+09
# 2018    5.294136e+09
# 2019    5.504932e+09
# dtype: float64

# %%
data[vertical].mode
# Out:
# <bound method DataFrame.mode of                                 2010    2011    2012    2013    2014    2015  \
# country
# Morocco                            0       0       0       0       0       0
# Botswana                           4       5       5       6       3       2
# Cape Verde                         4       5       5       5       3       3
# Chad                               4       5       5       5       3       3
# Tunisia                            5       3       2       2       4       3
# Mauritania                         6       6       6       0       0       3
# Egypt                             12       7       6       6       7       7
# Somalia                           57      53      63      67      71      83
# Benin                             60      65      68      70      62      51
# Mali                              67      76      65      87      56      69
# Senegal                           79      79      79      86      87      91
# ...

# %%
data[vertical].median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of                                 2010    2011    2012    2013    2014    2015  \
# country
# Morocco                            0       0       0       0       0       0
# Botswana                           4       5       5       6       3       2
# Cape Verde                         4       5       5       5       3       3
# Chad                               4       5       5       5       3       3
# Tunisia                            5       3       2       2       4       3
# Mauritania                         6       6       6       0       0       3
# Egypt                             12       7       6       6       7       7
# Somalia                           57      53      63      67      71      83
# Benin                             60      65      68      70      62      51
# Mali                              67      76      65      87      56      69
# ...

# %%
data.groupby('country').median().plot.bar(stacked=True)
plt.title('Median')
plt.show()

# %%
for year in range(2010,2020):
    data.plot.bar(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))

# %%
for year in range(2010,2020):
    data.plot.hist(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))

# %%
for year in range(2010,2020):
    data.plot.line(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))

# %%
for year in range(2010,2020):
    data.plot.kde(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))

# %%
print('from the data above it shows that a high number of african counties produce coffee, but Ethiopia is the leading poducer of coffee in Africa as it has been every year since 2010 up until now and Uganda has been the second leading producers in that span af time and this shows that Africa gains alot of revenue from the production of coffee ')
# Out:
# from the data above it shows that a high number of african counties produce coffee, but Ethiopia is the leading poducer of coffee in Africa as it has been every year since 2010 up until now and Uganda has been the second leading producers in that span af time and this shows that Africa gains alot of revenue from the production of coffee
